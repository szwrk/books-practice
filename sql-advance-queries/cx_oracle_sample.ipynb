# %%
import cx_Oracle
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# oracle 23ai free
dsn = cx_Oracle.makedsn("srv2.lan", 1521, service_name="free")
connection = cx_Oracle.connect("hr", "oracle", dsn)

query = "SELECT * FROM dual"
df = pd.read_sql(query, connection)
df.head()
# Out:
# C:\Users\Arek\AppData\Local\Temp\ipykernel_9492\720205111.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#   DUMMY
# 0     X

# %%
query = "SELECT * FROM employees"
df = pd.read_sql(query, connection)
df.head()
# Out:
# C:\Users\Arek\AppData\Local\Temp\ipykernel_14604\4036435384.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#    EMPLOYEE_ID FIRST_NAME LAST_NAME    EMAIL    PHONE_NUMBER  HIRE_DATE  \
# 0          100     Steven      King    SKING  1.515.555.0100 2013-06-17
# 1          101      Neena      Yang    NYANG  1.515.555.0101 2015-09-21
# 2          102        Lex    Garcia  LGARCIA  1.515.555.0102 2011-01-13
# 3          103  Alexander     James   AJAMES  1.590.555.0103 2016-01-03
# 4          104      Bruce    Miller  BMILLER  1.590.555.0104 2017-05-21
#
#     JOB_ID   SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0  AD_PRES  24000.0             NaN         NaN           90.0
# 1    AD_VP  17000.0             NaN       100.0           90.0
# ...

# %%
query = "SELECT * FROM employees"
df = pd.read_sql(query, connection)
df.describe()
# Out:
# C:\Users\Arek\AppData\Local\Temp\ipykernel_9492\4197435638.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#        EMPLOYEE_ID                      HIRE_DATE        SALARY  \
# count   107.000000                            107    107.000000
# mean    153.000000  2015-11-09 17:56:38.130841088   6461.831776
# min     100.000000            2011-01-13 00:00:00   2100.000000
# 25%     126.500000            2015-02-07 12:00:00   3100.000000
# 50%     153.000000            2016-01-03 00:00:00   6200.000000
# 75%     179.500000            2017-02-15 00:00:00   8900.000000
# max     206.000000            2018-04-21 00:00:00  24000.000000
# std      31.032241                            NaN   3909.579731
#
#        COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
df["FIRST_NAME"].unique()
# Out:
# array(['Steven', 'Neena', 'Lex', 'Alexander', 'Bruce', 'David', 'Valli',
#        'Diana', 'Nancy', 'Daniel', 'John', 'Ismael', 'Jose Manuel',
#        'Luis', 'Den', 'Shelli', 'Sigal', 'Guy', 'Karen', 'Matthew',
#        'Adam', 'Payam', 'Shanta', 'Kevin', 'Julia', 'Irene', 'James',
#        'Laura', 'Mozhe', 'TJ', 'Jason', 'Michael', 'Ki', 'Hazel',
#        'Renske', 'Stephen', 'Joshua', 'Trenna', 'Curtis', 'Randall',
#        'Peter', 'Alberto', 'Gerald', 'Eleni', 'Sean', 'Christopher',
#        'Nanette', 'Oliver', 'Janette', 'Patrick', 'Allan', 'Lindsey',
#        'Louise', 'Sarath', 'Clara', 'Danielle', 'Mattea', 'Sundar',
#        'Amit', 'Lisa', 'Harrison', 'Tayler', 'William', 'Elizabeth',
#        'Sundita', 'Ellen', 'Alyssa', 'Jonathon', 'Jack', 'Kimberely',
#        'Charles', 'Winston', 'Jean', 'Martha', 'Girard', 'Nandita',
#        'Alexis', 'Anthony', 'Kelly', 'Jennifer', 'Timothy', 'Sarah',
#        'Britney', 'Samuel', 'Vance', 'Alana', 'Donald', 'Douglas', 'Pat',
# ...

# %%
df["FIRST_NAME"].unique().sum()
# Out:
# '... ManuelTimothyClaraShantaAlanaMatthewNeenaEleni'

# %%
df["SALARY"].sum()
# Out:
# C:\Users\Arek\AppData\Local\Temp\ipykernel_9492\3061655116.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
# 691416.0

# %%
df[df["FIRST_NAME"] == "Steven"]
# Out:
# C:\Users\Arek\AppData\Local\Temp\ipykernel_9492\577989172.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#    FIRST_NAME
# 50     Steven
# 58     Steven

# %%
df[(df["SALARY"] >= 5000) & (df["SALARY"] <= 7000)]
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL    PHONE_NUMBER  HIRE_DATE  \
# 4            104      Bruce    Miller   BMILLER  1.590.555.0104 2017-05-21
# 13           113       Luis      Popp     LPOPP  1.515.555.0113 2017-12-07
# 23           123     Shanta   Vollman  SVOLLMAN  1.650.555.0123 2015-10-10
# 24           124      Kevin   Mourgos  KMOURGOS  1.650.555.0124 2017-11-16
# 55           155     Oliver   Tuvault  OTUVAULT  44.1632.960010 2017-11-23
# 61           161     Sarath    Sewall   SSEWALL  44.1632.960016 2016-11-03
# 65           165      David       Lee      DLEE  44.1632.960020 2018-02-23
# 66           166     Sundar      Ande     SANDE  44.1632.960021 2018-03-24
# 67           167       Amit     Banda    ABANDA  44.1632.960022 2018-04-21
# 73           173    Sundita     Kumar    SKUMAR  44.1632.960028 2018-04-21
# 78           178  Kimberely     Grant    KGRANT  44.1632.960033 2017-05-24
# ...

# %%
df.sort_values(by="SALARY", ascending=False).head(1)
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME  EMAIL    PHONE_NUMBER  HIRE_DATE  \
# 0          100     Steven      King  SKING  1.515.555.0100 2013-06-17
#
#     JOB_ID   SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0  AD_PRES  24000.0             NaN         NaN           90.0

# %%
df.groupby("JOB_ID")["DEPARTMENT_ID"].count()
# Out:
# JOB_ID
# AC_ACCOUNT     1
# AC_MGR         1
# AD_ASST        1
# AD_PRES        1
# AD_VP          2
# FI_ACCOUNT     5
# FI_MGR         1
# HR_REP         1
# IT_PROG        5
# MK_MAN         1
# MK_REP         1
# PR_REP         1
# PU_CLERK       5
# PU_MAN         1
# SA_MAN         5
# SA_REP        29
# SH_CLERK      20
# ST_CLERK      20
# ST_MAN         5
# Name: DEPARTMENT_ID, dtype: int64

# %%
sns.histplot(df["SALARY"], bins=10, kde=True)
plt.show()
# Out:
# Index(['DUMMY'], dtype='object')

# %%
query = "SELECT * FROM employees"
df = pd.read_sql(query, connection)
df_grouped = df.groupby("JOB_ID")["SALARY"].sum()
df_grouped.plot(x="DEPARTMENT_ID", y="SALARY", kind="bar", figsize=(8, 4))
df_grouped.plot(kind="bar", figsize=(8, 4))
plt.xlabel("Department ID")
plt.ylabel("Total Salary")
plt.title("Total Salary per Department")
plt.show()
# Out:
# C:\Users\Arek\AppData\Local\Temp\ipykernel_9492\2901338220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)

# %%
df["salary_level"] = df["SALARY"].apply(lambda x: "High" if x > 6000 else "Low")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SALARY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ...
